# %% [markdown]
# ### Elastic search request api

# %%
import json
import logging

import requests


def elasticsearch_curl(uri="http://localhost:9200/", json_body="", verb="get"):
    # pass header option for content type if request has a
    # body to avoid Content-Type error in Elasticsearch v6.0
    headers = {
        "Content-Type": "application/json",
    }
    resp = None
    try:
        # make HTTP verb parameter case-insensitive by converting to lower()
        if verb.lower() == "get":
            resp = requests.get(uri, headers=headers, data=json_body)
        elif verb.lower() == "post":
            resp = requests.post(uri, headers=headers, data=json_body)
        elif verb.lower() == "put":
            resp = requests.put(uri, headers=headers, data=json_body)
        elif verb.lower() == "del":
            resp = requests.delete(uri, headers=headers, data=json_body)
            return None

        # read the text object string
        try:
            resp_text = json.loads(resp.text)
        except:
            resp_text = resp.text

        # catch exceptions and print errors to terminal
    except Exception as error:
        logging.warning("resp:", resp)
        logging.warning("uri:", uri)
        logging.warning("\nelasticsearch_curl() error:", error)
        resp_text = None

    # return the Python dict of the request
    #     print ("resp_text:", resp_text)
    return resp_text


def del_all_scroll():
    response = elasticsearch_curl(
        uri="http://localhost:9200/_search/scroll/_all", verb="del"
    )
    return response


def del_pit(pit):
    json_data = json.dumps({"id": pit})
    response = elasticsearch_curl(
        uri="http://localhost:9200/_pit", json_body=json_data, verb="del"
    )
    return response


response = elasticsearch_curl("http://localhost:9200/wikipedia_sentences/_count")
print(response)
# Out:
# {'count': 126899105, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %% [markdown]
# ### Post a sentence to the index

# %%
def post_sentence(dict_object):
    # Post one example to news_event_frame index
    if dict_object:
        json_object = json.dumps(dict_object)
    else:
        return None
    response = elasticsearch_curl(
        "http://localhost:9200/wikipedia_sentences/_doc",
        verb="post",
        json_body=json_object,
    )
    return response


def query_sentence(phrase, size=100):
    dict_object = {
        "query": {
            "bool": {
                "must": [{"match_phrase": {"doc": phrase}}],
                "should": [
                    {"match_phrase": {"doc": "is a"}},
                    {"match_phrase": {"doc": "is not a"}},
                    {"match_phrase": {"doc": "have a"}},
                    {"match_phrase": {"doc": "does not have a"}},
                    {"match_phrase": {"doc": "is capable of"}},
                    {"match_phrase": {"doc": "is not capable of"}},
                ],
            },
        },
        "size": size,
    }

    json_object = json.dumps(dict_object)
    response = elasticsearch_curl(
        "http://localhost:9200/wikipedia_sentences/_search",
        verb="post",
        json_body=json_object,
    )
    result = []
    for item in response["hits"]["hits"]:
        score = item["_score"]
        doc = item["_source"]["doc"]
        result.append((doc, score))
    return result


def query_sentence_match(phrase):
    dict_object = {"query": {"match": {"doc": phrase}}, "size": 1}
    json_object = json.dumps(dict_object)
    response = elasticsearch_curl(
        "http://localhost:9200/wikipedia_sentences/_search",
        verb="post",
        json_body=json_object,
    )
    result = []
    for item in response["hits"]["hits"]:
        score = item["_score"]
        doc = item["_source"]["doc"]
        result.append((doc, score))
    return result


def bulk_post(bulk_dict_data, index_name="wikipedia_sentences"):
    if len(bulk_dict_data) < 1:
        return None
    # Post multiple examples to an index
    # A list of data dict
    meta_json = json.dumps({"index": {"_index": index_name, "_type": "_doc"}})
    data_to_post = (
        "\n".join(meta_json + "\n" + json.dumps(d) for d in bulk_dict_data) + "\n"
    )
    response = elasticsearch_curl(
        f"http://localhost:9200/_bulk", verb="post", json_body=data_to_post,
    )
    return response


# test_data_dict = [{"doc": "This is a test text."} for i in range(500000)]
# response = post_sentence(test_data_dict)
# # print(response)
# response = bulk_post(test_data_dict)
# print(response)

response = query_sentence("animal has a")
response
# Out:
# [('Each animal has a name.\n', 16.058651),
#  ('Each animal has a specific name.\n', 15.583131),
#  ('The animal has a broad foot.\n', 15.583131),
#  ('The animal has a long siphon.\n', 15.583131),
#  ('The animal has a long siphon.\n', 15.583131),
#  ('The animal has a uniform light colour.\n', 15.134964),
#  ('The living animal has a general orange coloration.\n', 14.711854),
#  ('The animal has a distinct head and tail.\n', 14.711854),
#  ('Each animal has a subdermal tracking microchip implant.\n', 14.711854),
#  ('The living animal has a general orange color.\n', 14.711854),
#  ('This animal has a large, uniform, and sutureless braincase.\n', 14.311757),
#  ('The population of C. fulvus has not been quantified but the animal has a wide range and is presumed to have a large total population.\n',
#   14.114789),
#  ('The animal has a conspicuously large, long-haired tail, measuring .\n',
#   13.932846),
#  ('The animal has a tendency to place everything in its mouth.\n', 13.573481),
#  ('The animal has a large head on a very flexible neck.\n', 13.573481),
#  ('The animal has a broad creeping foot and a developed mantle.\n', 13.573481),
#  ('How can one show that an animal has a good memory?\n', 13.573481),
#  ('The animal has a large skull with a square-shaped neurocranium.\n',
#   13.573481),
#  ('Each animal has a small eye shaped like a pointed oval.\n', 13.573481),
#  ('The average fossorial animal has a basal rate between 60% and 90%.\n',
#   13.232189),
#  ('As is typical in the Neogastropoda, the animal has a long siphon.\n',
#   13.232189),
#  ('The animal has a strong sense of smell and large anal glands.\n',
#   13.232189),
#  ('The main symptom is the animal has a wet tail, matted with faeces.\n',
#   12.907638),
#  ('The animal has a plumate gill, at the right side of the head.\n',
#   12.907638),
#  ('The animal has a distinct head and trunk with a forward sail-like (1.\n',
#   12.598626),
#  ('The animal has a broad emarginate head with one pair of long slender tentacles.\n',
#   12.598626),
#  ('Each animal has a uniquely identifying, frequency-modulated narrow-band signature vocalization (signature whistle).\n',
#   12.598626),
#  ('The animal has a stout rounded muzzle, short stout tentacles and large black eyes.\n',
#   12.598626),
#  ('Each animal has a mechanical respiratory system, giving the sculptures an appearance of life.\n',
#   12.598626),
#  ('The animal has a broad emarginate head with one pair of long slender tentacles.\n',
#   12.598626),
#  ('Each animal has a home range of one to one and a half hectares.\n',
#   12.598626),
#  ('The animal has a great regenerative capacity and will regrow the lost parts later.\n',
#   12.598626),
#  ('Thus, each animal has a specific movement technique in addition to its 8 striking methods.\n',
#   12.304066),
#  ('The body of the animal has a large defect caused by the degenerated tin filling.\n',
#   12.304066),
#  ('The left-hand animal has a long tail and round paws with five articulated digits.\n',
#   12.304066),
#  ('The right-hand animal has a shorter tail, and its legs end in cloven hoofs.\n',
#   12.304066),
#  ('The head and foot of the animal has a yellow-orange color with brown spots.\n',
#   12.304066),
#  ("This animal has a mouth with special jaws (Aristotle's lantern) located on the bottom (oral) surface.\n",
#   12.022963),
#  ('The animal has a distinct  lateral fringe of the foot, with three filaments on each side.\n',
#   12.022963),
#  ('Each story followed a similar formula in that typically each animal has a distinct personality trait.\n',
#   12.022963),
#  ('The animal has a broad foot, longitudinally divided by a median line below, and tuberculate above.\n',
#   12.022963),
#  ('This animal has a white U-shaped patch on its rump and has white by its eye.\n',
#   11.754417),
#  ('This animal has a distribution closely localised to Rheum populations, and has only been found in Turkey.\n',
#   11.754417),
#  ('This is associated with movement and bilateral symmetry, such that the animal has a definite head end.\n',
#   11.754417),
#  ('In each of the stories, every animal has a "personality" and each story ends in a moral.\n',
#   11.754417),
#  ('A small bodied animal has a greater capacity to be more abundant than a large bodied one.\n',
#   11.754417),
#  ('In each of the stories every animal has a "personality" and each story ends in a moral.\n',
#   11.754417),
#  ('This animal has a large fragile shell and can grow up to 390\xa0mm in total length.\n',
#   11.754417),
#  ('Malcolm, at first, refuses to believe him because The Animal has a reputation of being a liar.\n',
#   11.754417),
#  ('As literally translated, the title of book is An Animal Has a Soul, (a Cat) Damn It!\n',
#   11.754417),
#  ('He concluded "if an animal has a propulsive surface on the end of its tail, it uses it".\n',
#   11.497607),
#  ('If the host animal has a blood-borne infection, the tick will ingest the pathogens with the blood.\n',
#   11.497607),
#  ('SET assumes that the animal has a clock, a working memory, a reference memory, and a decision process.\n',
#   11.497607),
#  ('If any animal has a system of laws regulating the body politic, it is certainly the prairie dog".\n',
#   11.497607),
#  ("Distinctively different to other Rostanga'' species, this animal has a white notum with elongate, scattered, purple-brown spots.\n",
#   11.497607),
#  ('Each animal has a cheerful, optimistic head at one end and an unhappy, pessimistic head at the other.\n',
#   11.497607),
#  ('The animal has a large headshield with a deep median slit, separating it into two posteriorly projecting lobes.\n',
#   11.497607),
#  ('Inside the mantle cavity the animal has a highly vascularized area of tissue that functions as a lung.\n',
#   11.497607),
#  ('This animal has a fleshy blue tongue which is used to taste the air and scare off potential predators.\n',
#   11.251779),
#  ('Because the live animal has a light-emitting organ, it is also sometimes known as the tail-light squid.\n',
#   11.251779),
#  ('The animal has a gland at the end of its tail which is thought to emit pheromones during courtship.\n',
#   11.251779),
#  ('The animal has a tense posture, its front legs are stretched in front, and its back legs are slightly bent.\n',
#   11.016242),
#  ('This animal has a pointed rostrum and beady black eyes, hind limbs longer than the forelimbs, and large hind feet.\n',
#   11.016242),
#  ('The animal has a head and body length of 13–21\xa0cm and a tail length of 12–20\xa0cm.\n',
#   11.016242),
#  ('"Making Sense" (23 January 1989): Each animal has a unique view of the world derived from a combination of different senses.\n',
#   10.790363),
#  ('At the time it was stated that the animal has a large area of suitable habitat and seemed to be plentiful.\n',
#   10.790363),
#  ('The animal has a karyotype of 46 chromosomes, with a total of 50 major arms on the autosomes (non-sex chromosomes).\n',
#   10.790363),
#  ('The animal has a short, almost hairless snout and a rounded cranium, with a dark patch of fur on the forehead.\n',
#   10.790363),
#  ('This cut is typically fatty, and because the muscle is constantly used by the animal, has a great deal of flavor.\n',
#   10.790363),
#  ('The animal has a head surmounted by broad, rather long tentacles, formed like a pointed horn, and open on the side.\n',
#   10.790363),
#  ('The animal has a karyotype of 46 chromosomes, with a total of 50 major arms on the autosomes (non-sex chromosomes).\n',
#   10.790363),
#  ('This animal has a body length of 66–68\xa0cm, a tail length of 42–44\xa0cm and a weight of 4.\n',
#   10.573563),
#  ('The animal has a toxic bite, which it gets by licking a toxic secretion from glands on the inside of its elbows.\n',
#   10.573563),
#  ('The fur animals are housed in shelter buildings or halls, where each animal has a specific place marked with a kit card.\n',
#   10.573563),
#  ('This pink-skinned animal has a distinctive profile with an elongated, flattened snout, and highly protrusible jaws containing prominent nail-like teeth.\n',
#   10.573563),
#  ('When in the field, the initial question for every fair chase hunter is whether the animal has a reasonable opportunity to elude the hunter.\n',
#   10.165088),
#  ('The living animal has a mottled (blackish-brown and light tan) mantle with short and long colorless papillae, a blackish siphon and tan foot.\n',
#   10.165088),
#  ('Each plant or animal has a set length of time required for it to mature and become harvestable, with expedited growth in suitable climates.\n',
#   10.165088),
#  ('“If the animal has a local kisagalla name, we think that Sagalla people may recognize it for the special endemic species that it is.\n',
#   10.165088),
#  ('Ramidrejus are a very sought-after animal in Cantabrian folklore because their fur heals every sickness and the animal has a strong desire for gold.\n',
#   9.97246),
#  ('The length of the specimen, from the rostrum to the tail is  – of which  is the rostrum – and the animal has a maximum width of .\n',
#   9.97246),
#  ('The animal has a sturdy skeleton and a short, muscular upper body with proportionately long upper limbs that contribute to its climbing and grasping abilities.\n',
#   9.97246),
#  ('The animal has a mane that runs from the horns to the middle of the dorsal aspect of the animal between the scapulae covering the skin.\n',
#   9.786997),
#  ('In cases when an animal has a lot of fluid in the abomasum, a gastric-rumen tube should be used to help extract the extra fluid.\n',
#   9.786997),
#  ('"Satisfying" and "dissatisfying" conditions are determined behaviorally, and they cannot be accurately predicted, because each animal has a different idea of these two terms than another animal.\n',
#   9.608308),
#  ('Like most in this genus the animal has a large muscular mantle, folds of which can completely cover the whitish shell, giving it a slug-like appearance.\n',
#   9.608308),
#  ('Another similar study that involved energetically challenging small mammals showed that diurnality is most beneficial when the animal has a sheltered location to rest in, reducing heat loss.\n',
#   9.436025),
#  ('Unless an animal has a sure indication that they will win without injury, or the resources are valuable enough for the risk of death, animals usually avoid fighting.\n',
#   9.436025),
#  ('The animal has a karyotype of 2n=44 and FN=54, which consists of five pairs of four-armed chromosomes and sixteen pairs of two-armed (telocentric) chromosomes.\n',
#   9.436025),
#  ('There are teeth at the edge of the shell and the animal has a muscular foot, gills, siphons, mouth and gut and is surrounded by a mantle inside the shell.\n',
#   9.109354),
#  ('The animal has  a flattened head, which supports a pair of pretty long, thick, and conical tentacles, with a small protuberance at their base, internally, where the eyes are situated.\n',
#   9.109354),
#  ('There are teeth at the edge of the shell, and the animal has a muscular foot, gills, siphons, mouth and gut and is surrounded by a mantle inside the shell.\n',
#   9.109354),
#  ('There are teeth at the edge of the shell and the animal has a muscular foot, gills, siphons, mouth and gut and is surrounded by a mantle inside the shell.\n',
#   9.109354),
#  ('If the animal has a heavy work load, works on abrasive footing, needs additional traction, or has pathological changes in the hoof or conformational challenges, then shoes may be required.\n',
#   9.109354),
#  ('The adult animal has a very large, solid and heavy shell, with knob-like spines on the shoulder, a flared, thick outer lip, and a characteristic pink or orange aperture (opening).\n',
#   8.954356),
#  ('She\'s a vegetarian, believing that every animal has a right to live, and is vocal in her opinions, which are not necessarily grounded in reality but stem from a good heart".\n',
#   8.954356),
#  ('Post-LaVeyan Satanists, like the adherents of The Satanic Temple, argue that the human animal has a natural altruistic and communal tendency, and frame Satan as a figure of struggle against injustice and activism.\n',
#   8.519472),
#  ('The bridge, a design of which reminds of a marine animal, has a curvy steel and glass canopy top which shimmers with an interactive light display at night, generated by thousands of white LEDs.\n',
#   8.519472),
#  ('Hoof boots can also be used as a protective device when the animal has a hoof injury that requires protection of the sole of the hoof, or to aid in the application of medication.\n',
#   8.519472),
#  ('These objections are on the grounds of "fair chase", the idea that an animal has a fair chance of escaping the hunter, and it\'s not too easy for the hunter to kill the animal.\n',
#   8.519472)]

# %% [markdown]
# ### Insert sentences into elastic index

# %%
data = []
jsonfilename = "../data/LeapOfThought/mask-filling/lot_train.txt"
with open(jsonfilename) as f:
    input_lines = f.readlines()
    for line in input_lines:
        data.append(line)
    print(len(data))
jsonfilename = "../data/LeapOfThought/mask-filling/lot_test.txt"
with open(jsonfilename) as f:
    input_lines = f.readlines()
    for line in input_lines:
        data.append(line)
    print(len(data))
jsonfilename = "../data/LeapOfThought/mask-filling/lot_dev.txt"
with open(jsonfilename) as f:
    input_lines = f.readlines()
    for line in input_lines:
        data.append(line)
    print(len(data))
# Out:
# 9793
# 10158
# 10510

# %%
import random
import string

from tqdm.auto import tqdm

count = lambda l1, l2: sum([1 for x in l1 if x in l2])


def count_punc(s):
    return count(s, set(string.punctuation))


def count_keyword(s, key):
    count = 0
    s = s.replace(".", "").replace("\n", "")
    for w in s.split(" "):
        if w.lower() == key:
            count += 1
    return count


source_neural_sent_dic = {}
outfilename = "../data/LeapOfThought/mask-filling/lot_neutral.txt"
with open(outfilename, "w") as f:
    for item in tqdm(data):
        ## Get source and objective
        sens, obj = item.split("\t")
        obj = obj.strip()
        sen_li = sens.split(". ")
        for sen in sen_li[:-1]:
            sen_ws = sen.split(" ")
            for w in sen_ws:
                if sen.replace(w, "<MASK>") + "." == sen_li[-1]:
                    source = w
                    source_sent = sen
                    break
        ## Get top 10 sentences from wikipedia by source
        #         print(f"source:{source}\n target:{obj}\n source_sent:{source_sent}")
        if source in source_neural_sent_dic:
            out_sentence = item.strip() + "\t" + source_neural_sent_dic[source]
            f.write(out_sentence)
            continue
        size = 10
        top_query_sent = query_sentence(source, size)
        query_replace_score = []
        ### For each of the 10 sentence, reformulate it by the object word, and then get the one with the lowest similary score in its top-1 result.
        ### This means the word in that sentence is unlikely repalced by the object.
        for sent in top_query_sent:
            query_replace_sen = sent[0].replace(source, obj)
            diff_len = abs(
                (len(query_replace_sen.split(" ")) - len(source_sent.split(" ")))
                / min(len(query_replace_sen.split(" ")), len(source_sent.split(" ")))
            )
            if (count_punc(sent[0]) > 1) or (  ## Less than one punctuation
                count_keyword(sent[0], source) > 1
            ):  ## Less than one source word
                query_top_1_score = 100
            else:
                query_top_1_sen, query_top_1_score = query_sentence_match(
                    query_replace_sen
                )[0]
            if (diff_len > 2) or (
                len(query_replace_sen.replace("  ", " ").split(" ")) < 4
            ):
                ## The length differnce between the select sent and the source sent should be less than 2 times.
                query_top_1_score = 200
            query_replace_score.append(query_top_1_score)
        best_sen_index = query_replace_score.index(min(query_replace_score))
        best_sen = top_query_sent[best_sen_index][0]
        source_neural_sent_dic[source] = best_sen
        out_sentence = item.strip() + "\t" + best_sen

        #             if query_replace_score[best_sen_index] < 100:
        #                 best_sen = top_query_sent[best_sen_index][0]
        #                 out_sentence = item.strip() + "\t" + best_sen
        #                 break
        #             else:
        #                 if len(top_query_sent) != size or size>500:
        #                     best_sen_index = random.randomint(0, len(top_query_sent) - 1)
        #                     best_sen = top_query_sent[best_sen_index][0]
        #                     out_sentence = item.strip() + "\t" + best_sen
        #                     break
        #                 size += 100

        f.write(out_sentence)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10510.0), HTML(value='')))

# %%
len(data), len(source_neural_sent_dic)
# Out:
# (10510, 326)

# %%
source_neural_sent_dic
# Out:
# {'energy': 'A single wave or photon does not have a center of momentum frame where its energy must be at minimal value.\n',
#  'animal': 'The animal is capable of complete retraction within the shell.\n',
#  'fish': 'The fish does not have a lateral line.\n',
#  'person': 'A person who died a natural death does not have a malevolent ifrit.\n',
#  'element': 'The CCG does not have a "reserve" element.\n',
#  'covering': 'Victoria does not have a dedicated industry statute covering the taxi industry.\n',
#  'drug': 'There is not a single drug that is a standard among treatment.\n',
#  'illumination': 'He is a storyboard artist for Illumination Entertainment.\n',
#  'appearance': 'The image does not have a unified appearance.\n',
#  'leader': 'The party does not have a traditional leader.\n',
#  'individual': 'The individual does not have a foreign accent.\n',
#  'chemical': 'NOTT-202 is a two-part chemical compound that is capable of selectively absorbing carbon dioxide.\n',
#  'mammal': 'Max is a mammal.\n',
#  'man': 'A man is scared to go to heaven because he does not have a soul mate.\n',
#  'wood': 'It is capable of working mostly wood and plastics.\n',
#  'insect': 'A fly is a devilish insect.\n',
#  'bark': 'They have a loud bark.\n',
#  'quantity': 'The magnetic susceptibility of most crystals is not a scalar quantity.\n',
#  'food': 'Only episode with these obstacles that does not have a food obstacle.\n',
#  'weather': 'Lamanon does not have a weather station, the nearest being in Salon-de-Provence.\n',
#  'fabric': 'Stretch fabric is a synthetic fabric that stretches.\n',
#  'nourishment': 'Proper nourishment is a constant struggle for many Bolivians.\n',
#  'instrument': 'The instrument does not have a direct equivalent among traditional Vietnamese musical instruments.\n',
#  'platform': 'It also does not have a platform or metal bar.\n',
#  'vertebrate': 'Vertebrate predation is not a major threat to black corals.\n',
#  'traveler': 'He is a left fellow traveler.\n',
#  'game': 'The game does not have a direct sequel.\n',
#  'sport': 'Portugal does not have a long history in this sport.\n',
#  'football': 'The school does not have a football team.\n',
#  'location': 'The Empathy Museum does not have a permanent location.\n',
#  'region': 'Yet, it still does not have a Region 1 release.\n',
#  'trait': 'Procrastination is not a lifelong trait.\n',
#  'material': 'Adhesive transfer tape does not have a backing material.\n',
#  'emotion': 'Jealousy is not a single emotion.\n',
#  'building': 'The station does not have a station building.\n',
#  'merchant': 'Merchant is a Democrat.\n',
#  'vehicle': 'The vehicle does not have a reverse gear or brakes.\n',
#  'quality': 'Ofsted does not have a mandate to inspect the quality of home education.\n',
#  'science': 'Chicago Math and Science Academy does not have a selective enrollment process.\n',
#  'day': 'The United States does not have a Budget Day.\n',
#  'delicacy': 'It is a traditional delicacy.\n',
#  'surface': 'The sphere does not have a surface of centers.\n',
#  'servant': 'Footman is a servant.\n',
#  'disorder': 'Homosexuality is not a mental disorder.\n',
#  'barrier': 'Crash Barrier: The enclosed crash barrier is capable of testing vehicles up to 10,000\xa0lbs.\n',
#  'disease': 'It is capable of causing infectious disease in humans.\n',
#  'room': 'Their factory does not have a show room.\n',
#  'attendant': 'is a flight attendant.\n',
#  'period': 'It does not have a rest period unless water is withheld.\n',
#  'activity': 'Platinum forms strong bonds with carbon and does not have a catalytic activity in this type of reaction.\n',
#  'road': 'The northeast part does not have a passable road.\n',
#  'clothing': 'They also have a private clothing brand.\n',
#  'decoration': 'This painting is a decoration.\n',
#  'paper': 'The Consultation Paper does not have a preferred option.\n',
#  'meal': 'They have a meal with Santiago.\n',
#  'reptile': 'A lizard is a reptile.\n',
#  'machine': 'It does not have a fax machine.\n',
#  'craft': 'The patrol craft have a basic design.\n',
#  'feeling': 'It is not a feeling.\n',
#  'ballroom': 'Huffman is a ballroom dancer.\n',
#  'house': 'The main house does not have a fireplace.\n',
#  'officer': 'Since it is not a Section 10400 corporation, it does not have a humane officer who is authorized to pursue legal action against violators of anticruelty criminal laws.\n',
#  'earth': 'Fallen Earth does not have a fixed class system.\n',
#  'construction': 'The quadrature of the circle does not have a solid construction.\n',
#  'parent': 'I-238 does not have a parent.\n',
#  'compound': 'It is not a ionic compound.\n',
#  'herb': 'It is a perennial herb.\n',
#  'pain': 'Its venom is capable of causing significant pain and numbness.\n',
#  'storm': 'Storm Online is not a grind feast MMORPG.\n',
#  'light': 'Chelsea does not have a link to the MBTA subway or light rail systems.\n',
#  'church': 'The commune does not have a church.\n',
#  'salamander': "Dunn's salamander is a moderately sized, terrestrial salamander.\n",
#  'commodity': 'Labour is not a commodity.\n',
#  'motor': 'Spinal manipulative does not have a significant benefits over motor control exercises.\n',
#  'pigeon': 'Ice pigeon is a fancy pigeon breed.\n',
#  'education': 'He does not have a formal education and was trained by his father.\n',
#  'lamp': 'This is not a common arm lamp system.\n',
#  'mineral': 'Jeffersonite is not a recognized mineral name.\n',
#  'vegetable': 'Kale is a vegetable.\n',
#  'cat': 'But she is not a cat.\n',
#  'joy': 'Confession is a joy?\n',
#  'art': 'Feng Boyi explains that modern, experimental art does not have a place currently in Chinese art exhibitions.\n',
#  'pup': 'Apricot is a hedgehog pup.\n',
#  'boat': 'The boat is capable of offshore sailing.\n',
#  'sound': 'The Korean alphabet does not have a letter for w sound.\n',
#  'cloth': 'This is a cloth case that is constructed from boards that have a cloth upholstering.\n',
#  'bag': 'They have a whole bag full of it.\n',
#  'dam': 'The dam wall does not have a spillway.\n',
#  'book': 'It is the only Narnia book that does not have a main villain.\n',
#  'hair': 'Hair cells is capable of one action potential propagation for one vesicle release.\n',
#  'assistant': 'An assistant king does not have a Queen-mother as his title is not hereditary.\n',
#  'garment': '… Hope is a new garment.\n',
#  'formation': 'There has been some suggestion that the formation of NFTs does not have a causal relationship with disease.\n',
#  'gear': 'The vehicle does not have a reverse gear or brakes.\n',
#  'precipitation': 'Precipitation is plentiful throughout the year and Hamilton does not have a dry season month, a month where on average less than  of precipitation falls.\n',
#  'shape': 'It does not have a regular geometric shape.\n',
#  'cutlery': 'Clauss Cutlery is a cutlery brand owned by the Acme United Corporation since 2004.\n',
#  'radiation': 'Ionizing radiation is not a particularly strong mutagen.\n',
#  'water': 'The town does not have a water or sewage utility system.\n',
#  'metal': 'It also does not have a platform or metal bar.\n',
#  'tissue': 'This eye patch does not have a lens, but is composed of retinal tissue.\n',
#  'bread': 'Tunisian Khobz Tabouna is not a flat or pita like bread.\n',
#  'worker': 'This eusocial species does not have a normal worker caste.\n',
#  'emperor': 'Emperor Napoleon III chose not to have a coronation ceremony.\n',
#  'job': 'He does not have a job for the village though.\n',
#  'bottle': 'They have a bottle of champagne on ice.\n',
#  'corn': 'Adult corn snakes have a body length of .\n',
#  'coat': 'The municipality does not have a coat-of-arms.\n',
#  'biome': 'The island is a home to a large mangrove forest biome.\n',
#  'bush': 'It is a bush.\n',
#  'medicine': 'Westernized medicine does not have a long history in Nigeria or for the Hausa people.\n',
#  'noise': 'Each of which is capable of generating sawtooth, triangle, pulse, or noise waveforms.\n',
#  'flask': 'A hip flask is a thin flask for holding liquor.\n',
#  'painting': 'Currently, Trump does not have a portrait painting commissioned.\n',
#  'spacecraft': 'The spacecraft have a planned lifespan of five years.\n',
#  'restaurant': "As one of Kruger's smaller major camps, Crocodile Bridge does not have a full restaurant.\n",
#  'table': 'Unusual for its era, the table Bad Cats does not have a multi-ball.\n',
#  'criminal': 'He does not have a prior criminal history.\n',
#  'official': 'Ishkashimi is a threatened language that does not have a status of official language in the regions of its use.\n',
#  'bone': 'Despite his fierce appearance, he does not have a mean bone in his body.\n',
#  'chicken': 'The Blue Hen is not a recognized chicken breed.\n',
#  'shelter': 'OldDog Haven does not have a shelter.\n',
#  'passenger': 'The village currently does not have a passenger train station.\n',
#  'wave': 'Cape Discovery is capable of operating at wind speeds of  and wave heights of .\n',
#  'blubber': 'All whales have a thick layer of blubber.\n',
#  'solid': 'The quadrature of the circle does not have a solid construction.\n',
#  'tube': 'Fibril field: Magnetic flux tube that does not have a magnetic field outside the tube.\n',
#  'server': 'The simulation server does not have a GUI of its own.\n',
#  'ground': 'Since then the city does not have a cricket ground.\n',
#  'dish': 'There is not a dish where cereals are not present.\n',
#  'season': 'The area does not have a predictable dry season.\n',
#  'cloud': 'The personal cloud is not a tangible entity.\n',
#  'belief': 'There is a sexist belief that football is not a sport for women.\n',
#  'engine': 'The engine does not have a harmonic balancer.\n',
#  'artist': 'It does not have a specified artist.\n',
#  'interval': 'Melioration is capable of accounting for behavior on both concurrent ratio and concurrent interval schedules.\n',
#  'liquid': 'Solex in both liquid and crystallized form is capable of producing immense power.\n',
#  'monster': "Summon Nature's Ally differs from Summon Monster in the kind of creatures it is capable of summoning.\n",
#  'thief': 'He swears that he is not a thief.\n',
#  'scientist': 'Orman is not a political scientist hunkered down in the Ivory Tower.\n',
#  'side': 'The coracoid does not have a clear process to contact the side of the breastbone.\n',
#  'ice': 'Its hull is not capable of breaking through heavy ice during the winter season.\n',
#  'secretary': "The Cabinet Secretary does not have a political appointment such as Secretary of State and is not a member of the Cabinet, but is the professional Head of Her Majesty's Civil Service.\n",
#  'bubble': 'Bubble is a taxi driver.\n',
#  'deer': 'All deer have a liver without a gallbladder.\n',
#  'coast': 'The Coast Guard Auxiliary does not have a military chain of command.\n',
#  'wine': 'is not a fortified wine.\n',
#  'berry': 'The fruit is a berry.\n',
#  'seed': 'It is capable of year round flowering and seed set.\n',
#  'crime': 'Wyoming does not have a hate crime law.\n',
#  'dog': 'Maria does not have a dog.\n',
#  'field': 'It does not have a delicate sensual field.\n',
#  'player': 'The player does not have a weapon in this game mode.\n',
#  'wind': 'The wind farm is capable of producing 46.\n',
#  'cereal': 'The cereal did not have a slogan.\n',
#  'woman': 'She is a woman that always does right by everyone and does not have a single flaw in the novel.\n',
#  'stem': 'The fruit body does not have a partial veil or a ring on the stem.\n',
#  'cattle': 'The cattle have a feisty reputation.\n',
#  'anger': 'The Anger is a 27.\n',
#  'container': 'The research vessel is capable of carrying one container on its aft deck.\n',
#  'tool': 'It is not a diagnostic tool.\n',
#  'salt': '(3) Therefore, Cerebos is not a salt.\n',
#  'butterfly': 'Males have a butterfly shaped vocal marking.\n',
#  'cord': 'We will not have a vocal cord left.\n',
#  'lifeguard': 'It does not have a lifeguard.\n',
#  'grass': 'The Nolina bigelovii plant is not a grass.\n',
#  'boundary': 'Unlike Melbourne, Ballarat does not have a defined urban growth boundary.\n',
#  'grassland': 'A steppe is a dry grassland.\n',
#  'song': 'New Jersey does not have a state song.\n',
#  'temperature': 'The microscopic statistical mechanical definition does not have a reference temperature.\n',
#  'ship': 'The ship is not capable of operating aircraft.\n',
#  'boa': 'Stomias boa boa is a long, slender fish.\n',
#  'drink': 'Wilhelm and Laerte have a drink together.\n',
#  'pasta': 'Pasta alla gricia is a pasta dish of Roman origins.\n',
#  'jazz': 'He has said that he is not a jazz musician.\n',
#  'fowl': 'Fowl Weather is a 1953 Warner Bros.\n',
#  'daylight': 'as his crew would have a better chance of sighting submarines in daylight.\n',
#  'money': 'He does not have a job and is constantly after Gabbie to give him money.\n',
#  'shore': 'The CB90 is capable of landing troops directly on the shore.\n',
#  'equipment': 'The equipment is capable of analyzing both analog and digital signals.\n',
#  'photographer': 'is a Japanese photographer.\n',
#  'waste': 'Iqaluit does not have a recycling program in place; all recyclable materials are sent into the waste stream.\n',
#  'length': 'It DOES NOT have a Tag length nor any associated data.\n',
#  'nut': 'Some guitars have a rolling nut.\n',
#  'treatment': 'The plant does not have a treatment plant for effluents.\n',
#  'tooth': 'Bengalis have a sweet tooth.\n',
#  'pullover': '2 dress with pullover.\n',
#  'fuel': 'The 912 is capable of up to  fuel economy.\n',
#  'madam': 'Madam, you have a dangerous dog".\n',
#  'expert': 'The Expert Race serves as the race that allows anyone that is capable of paddling the whitewater.\n',
#  'plaything': 'Ideas were his plaything.\n',
#  'conductor': 'Nowadays, the orchestra does not have a principal conductor.\n',
#  'helping': 'Also helping with jaw expansion is the fact that its mouth does not have a floor.\n',
#  'serpent': 'Their leaders have a serpent emblem.\n',
#  'sweater': 'Behind each door is a sweater.\n',
#  'ape': 'She obviously is not a Homo sapien nor an ape (Hominidae).\n',
#  'auto': 'It is capable of auto navigation and interaction with its environment.\n',
#  'amphibian': 'Rhinesuchus is a large temnospondyl amphibian.\n',
#  'mill': 'The southern section of the road around New Mill does not have a secondary route.\n',
#  'motorbike': 'She is a sports person and motorbike enthusiast.\n',
#  'furniture': 'In addition 9000 have a job in furniture production.\n',
#  'alsatian': 'The traditional Alsatian costume is a symbol of the region.\n',
#  'clock': 'Here he is unable to deliver the mail on time because he does not have a clock.\n',
#  'particle': 'Until measured, a particle does not have a physical position.\n',
#  'flag': 'The Air Defense Forces does not have a flag.\n',
#  'nutriment': 'The cessation of nutriment is the cessation of craving.\n',
#  'lake': 'Fox Lake has eight islands one of with does not have a name.\n',
#  'care': 'The angel-faced child is carefully taken care of, as he does not have a mother.\n',
#  'spaniel': 'Bill is a Cocker Spaniel.\n',
#  'moth': 'The living moth may have a greenish cast.\n',
#  'mother': 'An assistant king does not have a Queen-mother as his title is not hereditary.\n',
#  'meat': 'Chocolate salami is not a meat product.\n',
#  'wasp': 'These wasp have a solitary lifestyle.\n',
#  'priest': 'But he is not a priest.\n',
#  'machinery': 'is a Japanese machinery manufacturer.\n',
#  'bottom': 'It needs a stand as it does not have a flat bottom.\n',
#  'aircraft': 'The ship is not capable of operating aircraft.\n',
#  'fiber': 'A low-fiber diet is not a no-fiber diet.\n',
#  'rider': 'is a Japanese motorcycle rider.\n',
#  'horse': 'A rider needs to verify with a veterinarian that the horse does not have a dental problem.\n',
#  'fence': 'There is a picket fence.\n',
#  'entertainment': 'Ramachander of Entertainment One gave the film  stars and said "Romeo does not have a great story but has a screenplay, which never lets you down.\n',
#  'valley': 'Penn Valley does not have a mayor or city council.\n',
#  'hotel': 'The hotel does not have a casino.\n',
#  'bat': 'Since the original text does not have a literal word for "granddaughter", the word bat ("daughter") was used in both cases.\n',
#  'aeroplane': 'He is a former aeroplane pilot.\n',
#  'headman': 'They have a traditional caste council, headed by headman known as a mukhiya.\n',
#  'pleasure': 'They have a zest for life and pleasure.\n',
#  'chair': 'There is a provision to have a Vice Chair-person if needed.\n',
#  'cleaner': 'It is a cleaner fish.\n',
#  'gap': 'The wage gap is not a universal percentage across the US.\n',
#  'darkness': 'This is a world of darkness .\n',
#  'satellite': 'Unlike North America, the UK does not have a commercial satellite radio service.\n',
#  'bed': 'They have a total bed capacity of 643.\n',
#  'slop': 'I Really Like Slop!\n',
#  'candy': 'Her costume and magic have a candy motif.\n',
#  'orchid': 'The Orchid Conservation Coalition does not have a physical space beyond its internet site.\n',
#  'shame': 'That is a shame.\n',
#  'district': 'The district does not have a hospital.\n',
#  'time': 'The tree does not have a particular harvest time.\n',
#  'rectangle': 'The package itself is a rectangle.\n',
#  'illness': 'This temporary condition is not a clinical illness or a personality disorder.\n',
#  'highway': 'Florence and the Shoals area does not have a direct link to an Interstate highway.\n',
#  'holiday': 'It is not a national holiday.\n',
#  'rattlesnake': 'Banded rock rattlesnake, blue rattlesnake, green rattlesnake, green rock rattlesnake, rock rattlesnake.\n',
#  'viper': 'Rock viper, coastal viper, Ottoman viper, Turkish viper, Near East viper, mountain viper.\n',
#  'trawler': 'It is a former fishing trawler.\n',
#  'mouse': 'The Aztec mouse is not a threatened species.\n',
#  'gun': 'A special gun that is capable of changing team and energizing packs.\n',
#  'leisure': 'Travel for leisure is not a valid purpose.\n',
#  'cod': 'Cow cod is a rural delicacy.\n',
#  'bee': 'Bee is not a simple, straightforward girl.\n',
#  'robin': 'All divisions will have a double round robin elimination.\n',
#  'pickle': 'Garlic pickle is a popular spicy pickle in Andhra Pradesh.\n',
#  'nose': 'Jot does not have a nose.\n',
#  'fear': 'She is a talented soccer player who seems to have a fear of insects and spiders.\n',
#  'examination': 'Did not have a physical examination requirement.\n',
#  'whale': '"A fed whale is a dead whale".\n',
#  'triangle': 'Each of which is capable of generating sawtooth, triangle, pulse, or noise waveforms.\n',
#  'trial': 'If the defendant does not have a reasonable excuse, the trial must proceed without them.\n',
#  'barber': 'He is a barber.\n',
#  'delight': 'His presence is a delight.\n',
#  'raglan': 'Raglan is a community in Ontario.\n',
#  'crystal': 'It is capable of crystal sync at 24 and 25 or 29.\n',
#  'elephant': 'Elephant is NOT a fantasy.\n',
#  'tower': 'The airport does not have a control tower.\n',
#  'duck': 'He is not a duck.\n',
#  'oil': 'The complex is capable of refining  of crude oil per day.\n',
#  'climber': 'It is a good climber.\n',
#  'protection': 'This protection is capable of withstanding 100 year floods.\n',
#  'excitement': "'Excitement' is not a word to use for this album .\n",
#  'stream': 'The stream does not have a specific source.\n',
#  'worship': 'This verse is not a total rejection of communal worship.\n',
#  'glove': 'They all have a baseball glove to help.\n',
#  'dough': 'However, the dough should be let overnight to have a perfect dough.\n',
#  'crockery': 'Cutlery and crockery are provided.\n',
#  'backwoodsman': 'Upper Canada  by a backwoodsman.\n',
#  'chimp': 'CHIMP is not a dynamically balanced walking robot.\n',
#  'soup': 'Ma Kuear Soup is not a soup.\n',
#  'president': 'The President of Finland does not have a vice president.\n',
#  'organelle': 'It is capable of movement by use of this organelle.\n',
#  'burglar': 'He reveals he is a burglar.\n',
#  'burrow': 'The nest is a burrow 0.\n',
#  'hat': 'Do You Have a Hat?\n',
#  'attempt': 'Blake takes Jacob home, but their attempt to have sex ends when Jacob does not have a condom.\n',
#  'raincoat': '"Famous Blue Raincoat" is a song by Leonard Cohen.\n',
#  'shade': 'Aegwareth is a human shade.\n',
#  'dandelion': 'The seeds have a "parachute" similar to the dandelion.\n',
#  'bear': 'Leeky is capable of shapeshifting into the form of a dire bear.\n',
#  'gull': 'The relict gull or  Central Asian gull (Ichthyaetus relictus) is a medium-sized gull.\n',
#  'pouch': 'Both sexes have a throat pouch.\n',
#  'courier': 'All players have a basic courier at the beginning.\n',
#  'flapjack': 'Khruschev fought back with a flapjack.\n',
#  'newsagent': 'There is a newsagent near the ticket hall.\n',
#  'cambric': 'The resulting triangular structure appears to have been covered with cambric.\n',
#  'bricklayer': 'He was a bricklayer.\n',
#  'dye': 'It is a fluorescent dye.\n',
#  'pirate': 'He is a pirate.\n',
#  'biosphere': 'The Biosphere 2 is a 3.\n',
#  'fog': 'All styles of fog nozzles have a spray pattern adjustment.\n',
#  'usage': 'The usage fee is not a copyright fee.\n',
#  'editor': 'It is not a full UML editor.\n',
#  'alligator': 'An alligator is a large kind of reptile.\n',
#  'anniversary': 'Gokaiger is a special anniversary series.\n',
#  'soya': 'Soya bean milk is a drink made from soaked, ground, and sieved soya bean.\n',
#  'destination': 'Älpelekopf is not a typical tourist destination.\n',
#  'foxhound': 'His dog is a foxhound named Rex.\n',
#  'guy': 'We have a guy.\n',
#  'lioness': 'Transforms into a lioness.\n',
#  'goat': 'Suzie is a goat.\n',
#  'georgette': 'The Conqueror is a novel written by Georgette Heyer.\n',
#  'coin': 'Often a round coin will have a central hole.\n',
#  'bird': 'Rex is not a bird.\n',
#  'plant': 'The plant is capable of producing up to 60.\n',
#  'fruit': 'It however is not a Strange Fruit release.\n',
#  'alcohol': 'Alcohol detox is not a treatment for alcoholism.\n',
#  'flower': 'The flower spikes have a length of .\n',
#  'music': 'It does not have a music video.\n',
#  'tree': 'The tree does not have a particular harvest time.\n',
#  'plum': '1997 Why a Peach is not a Plum .\n',
#  'pod': 'Fruit is a pod.\n',
#  'drake': 'Sergeant Andrew Drake is a police officer.\n',
#  'polyphony': 'is a free 2006 PlayStation 2 game by Polyphony Digital.\n',
#  'escalator': ', the station does not have a ground-level vestibule or a connecting escalator.\n',
#  'acorn': 'The fruit is a large acorn 2.\n',
#  'gentian': "Gentiana newberryi is a species of gentian known by the common names alpine gentian and Newberry's gentian.\n"}
